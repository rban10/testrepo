# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %%time
df = pd.read_csv('SBAnational.csv')
# Out:
# DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
# Wall time: 3.03 s

# %%
df
# Out:
#         LoanNr_ChkDgt                            Name             City State  \
# 0          1000014003                  ABC HOBBYCRAFT       EVANSVILLE    IN
# 1          1000024006     LANDMARK BAR & GRILLE (THE)        NEW PARIS    IN
# 2          1000034009           WHITLOCK DDS, TODD M.      BLOOMINGTON    IN
# 3          1000044001   BIG BUCKS PAWN & JEWELRY, LLC     BROKEN ARROW    OK
# 4          1000054004     ANASTASIA CONFECTIONS, INC.          ORLANDO    FL
# ...               ...                             ...              ...   ...
# 899159     9995573004                    FABRIC FARMS  UPPER ARLINGTON    OH
# 899160     9995603000                    FABRIC FARMS         COLUMBUS    OH
# 899161     9995613003    RADCO MANUFACTURING CO.,INC.      SANTA MARIA    CA
# 899162     9995973006           MARUTAMA HAWAII, INC.         HONOLULU    HI
# 899163     9996003010  PACIFIC TRADEWINDS FAN & LIGHT           KAILUA    HI
#
#           Zip                            Bank BankState   NAICS ApprovalDate  \
# 0       47711                FIFTH THIRD BANK        OH  451120    28-Feb-97
# 1       46526                 1ST SOURCE BANK        IN  722410    28-Feb-97
# 2       47401         GRANT COUNTY STATE BANK        IN  621210    28-Feb-97
# 3       74012   1ST NATL BK & TR CO OF BROKEN        OK       0    28-Feb-97
# 4       32801         FLORIDA BUS. DEVEL CORP        FL       0    28-Feb-97
# ...       ...                             ...       ...     ...          ...
# 899159  43221  JPMORGAN CHASE BANK NATL ASSOC        IL  451120    27-Feb-97
# 899160  43221  JPMORGAN CHASE BANK NATL ASSOC        IL  451130    27-Feb-97
# 899161  93455  RABOBANK, NATIONAL ASSOCIATION        CA  332321    27-Feb-97
# 899162  96830                  BANK OF HAWAII        HI       0    27-Feb-97
# 899163  96734            CENTRAL PACIFIC BANK        HI       0    27-Feb-97
#
#        ApprovalFY  ...  RevLineCr  LowDoc  ChgOffDate  DisbursementDate  \
# 0            1997  ...          N       Y         NaN         28-Feb-99
# 1            1997  ...          N       Y         NaN         31-May-97
# 2            1997  ...          N       N         NaN         31-Dec-97
# 3            1997  ...          N       Y         NaN         30-Jun-97
# 4            1997  ...          N       N         NaN         14-May-97
# ...           ...  ...        ...     ...         ...               ...
# 899159       1997  ...          0       N         NaN         30-Sep-97
# 899160       1997  ...          Y       N         NaN         31-Oct-97
# 899161       1997  ...          N       N         NaN         30-Sep-97
# 899162       1997  ...          N       Y    8-Mar-00         31-Mar-97
# 899163       1997  ...          N       N         NaN         31-May-97
#
#         DisbursementGross  BalanceGross  MIS_Status ChgOffPrinGr  \
# 0             $60,000.00         $0.00        P I F       $0.00
# 1             $40,000.00         $0.00        P I F       $0.00
# 2            $287,000.00         $0.00        P I F       $0.00
# 3             $35,000.00         $0.00        P I F       $0.00
# 4            $229,000.00         $0.00        P I F       $0.00
# ...                   ...           ...         ...          ...
# 899159        $70,000.00         $0.00        P I F       $0.00
# 899160        $85,000.00         $0.00        P I F       $0.00
# 899161       $300,000.00         $0.00        P I F       $0.00
# 899162        $75,000.00         $0.00       CHGOFF  $46,383.00
# 899163        $30,000.00         $0.00        P I F       $0.00
#
#               GrAppv      SBA_Appv
# 0        $60,000.00    $48,000.00
# 1        $40,000.00    $32,000.00
# 2       $287,000.00   $215,250.00
# 3        $35,000.00    $28,000.00
# 4       $229,000.00   $229,000.00
# ...              ...           ...
# 899159   $70,000.00    $56,000.00
# 899160   $85,000.00    $42,500.00
# 899161  $300,000.00   $225,000.00
# 899162   $75,000.00    $60,000.00
# 899163   $30,000.00    $24,000.00
#
# [899164 rows x 27 columns]

# %%
# %%time
sns.distplot(df['Zip'],kde = True)
# Out:
# Wall time: 328 ms

# %%
# %%time
df['ApprovalFY'].value_counts()
# Out:
# Wall time: 27.5 ms
# 2006    76040
# 2007    71876
# 2003    58193
# 2005    52912
# 1995    45758
#         ...
# 1968        1
# 1962        1
# 1967        1
# 1965        1
# 1966        1
# Name: ApprovalFY, Length: 70, dtype: int64

# %%
import modin.pandas as pd

# %%
# !pip install modin[ray]
# Out:
# Requirement already satisfied: modin[ray] in c:\users\baner\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: packaging in c:\users\baner\anaconda3\lib\site-packages (from modin[ray]) (20.4)
# Requirement already satisfied: fsspec in c:\users\baner\anaconda3\lib\site-packages (from modin[ray]) (0.7.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\baner\anaconda3\lib\site-packages (from modin[ray]) (1.19.5)
# Requirement already satisfied: pandas==1.4.0 in c:\users\baner\anaconda3\lib\site-packages (from modin[ray]) (1.4.0)
# Requirement already satisfied: pyarrow>=4.0.1; extra == "ray" in c:\users\baner\anaconda3\lib\site-packages (from modin[ray]) (6.0.1)
# Requirement already satisfied: ray[default]>=1.4.0; extra == "ray" in c:\users\baner\anaconda3\lib\site-packages (from modin[ray]) (1.9.2)
# Requirement already satisfied: six in c:\users\baner\anaconda3\lib\site-packages (from packaging->modin[ray]) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\baner\anaconda3\lib\site-packages (from packaging->modin[ray]) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\baner\anaconda3\lib\site-packages (from pandas==1.4.0->modin[ray]) (2.8.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\baner\anaconda3\lib\site-packages (from pandas==1.4.0->modin[ray]) (2020.1)
# Requirement already satisfied: jsonschema in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (3.2.0)
# Requirement already satisfied: click>=7.0 in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (7.1.2)
# Requirement already satisfied: pyyaml in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (5.3.1)
# Requirement already satisfied: attrs in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (19.3.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.0.0)
# Requirement already satisfied: redis>=3.5.0 in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (4.1.2)
# Requirement already satisfied: grpcio>=1.28.1 in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.40.0)
# Requirement already satisfied: protobuf>=3.15.3 in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (3.17.3)
# Requirement already satisfied: filelock in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (3.0.12)
# Requirement already satisfied: aiohttp-cors; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (0.7.0)
# Requirement already satisfied: gpustat>=1.0.0b1; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.0.0b1)
# Requirement already satisfied: py-spy>=0.2.0; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (0.3.11)
# Requirement already satisfied: aioredis<2; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.3.1)
# Requirement already satisfied: smart-open; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (5.2.1)
# Requirement already satisfied: aiosignal; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.2.0)
# Requirement already satisfied: aiohttp>=3.7; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (3.8.1)
# Requirement already satisfied: colorful; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (0.5.4)
# Requirement already satisfied: requests; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (2.24.0)
# Requirement already satisfied: frozenlist; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.3.0)
# Requirement already satisfied: opencensus; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (0.8.0)
# Requirement already satisfied: prometheus-client>=0.7.1; extra == "default" in c:\users\baner\anaconda3\lib\site-packages (from ray[default]>=1.4.0; extra == "ray"->modin[ray]) (0.8.0)
# Requirement already satisfied: setuptools in c:\users\baner\anaconda3\lib\site-packages (from jsonschema->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (49.2.0.post20200714)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\baner\anaconda3\lib\site-packages (from jsonschema->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (0.16.0)
# Requirement already satisfied: deprecated>=1.2.3 in c:\users\baner\anaconda3\lib\site-packages (from redis>=3.5.0->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.2.13)
# Requirement already satisfied: psutil in c:\users\baner\anaconda3\lib\site-packages (from gpustat>=1.0.0b1; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (5.7.0)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in c:\users\baner\anaconda3\lib\site-packages (from gpustat>=1.0.0b1; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (7.352.0)
# Requirement already satisfied: blessed>=1.17.1 in c:\users\baner\anaconda3\lib\site-packages (from gpustat>=1.0.0b1; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.19.1)
# Requirement already satisfied: hiredis in c:\users\baner\anaconda3\lib\site-packages (from aioredis<2; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (2.0.0)
# Requirement already satisfied: async-timeout in c:\users\baner\anaconda3\lib\site-packages (from aioredis<2; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\baner\anaconda3\lib\site-packages (from aiohttp>=3.7; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (2.0.11)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\baner\anaconda3\lib\site-packages (from aiohttp>=3.7; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\baner\anaconda3\lib\site-packages (from aiohttp>=3.7; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (6.0.2)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\baner\anaconda3\lib\site-packages (from colorful; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (0.4.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\baner\anaconda3\lib\site-packages (from requests; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\baner\anaconda3\lib\site-packages (from requests; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\baner\anaconda3\lib\site-packages (from requests; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\baner\anaconda3\lib\site-packages (from requests; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (3.0.4)
# Requirement already satisfied: opencensus-context==0.1.2 in c:\users\baner\anaconda3\lib\site-packages (from opencensus; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (0.1.2)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0; python_version >= "3.6" in c:\users\baner\anaconda3\lib\site-packages (from opencensus; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (2.4.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\baner\anaconda3\lib\site-packages (from deprecated>=1.2.3->redis>=3.5.0->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.12.1)
# Requirement already satisfied: jinxed>=1.1.0; platform_system == "Windows" in c:\users\baner\anaconda3\lib\site-packages (from blessed>=1.17.1->gpustat>=1.0.0b1; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.1.0)
# Requirement already satisfied: wcwidth>=0.1.4 in c:\users\baner\anaconda3\lib\site-packages (from blessed>=1.17.1->gpustat>=1.0.0b1; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (0.2.5)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\users\baner\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\users\baner\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.54.0)
# Requirement already satisfied: ansicon; platform_system == "Windows" in c:\users\baner\anaconda3\lib\site-packages (from jinxed>=1.1.0; platform_system == "Windows"->blessed>=1.17.1->gpustat>=1.0.0b1; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (1.89.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\baner\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\baner\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\baner\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (4.2.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\baner\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus; extra == "default"->ray[default]>=1.4.0; extra == "ray"->modin[ray]) (0.4.8)

# %%
import ray
ray.shutdown()
ray.init()
import modin.pandas as pd
# Out:
# 2022-01-31 01:52:35,995	INFO services.py:1338 -- View the Ray dashboard at http://127.0.0.1:8265

# %%
# %%time
df = pd.read_csv('SBAnational.csv')
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\anaconda3\lib\site-packages\modin\pandas\io.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     133     _, _, _, f_locals = inspect.getargvalues(inspect.currentframe())
#     134     kwargs = {k: v for k, v in f_locals.items() if k in _pd_read_csv_signature}
# --> 135     return _read(**kwargs)
#     136
#     137
#
# ~\anaconda3\lib\site-packages\modin\pandas\io.py in _read(**kwargs)
#      58
#      59     squeeze = kwargs.pop("squeeze", False)
# ---> 60     pd_obj = FactoryDispatcher.read_csv(**kwargs)
#      61     # This happens when `read_csv` returns a TextFileReader object for iterating through
#      62     if isinstance(pd_obj, pandas.io.parsers.TextFileReader):
#
# ~\anaconda3\lib\site-packages\modin\core\execution\dispatching\factories\dispatcher.py in read_csv(cls, **kwargs)
#     178     @_inherit_docstrings(factories.BaseFactory._read_csv)
#     179     def read_csv(cls, **kwargs):
# --> 180         return cls.__factory._read_csv(**kwargs)
#     181
#     182     @classmethod
#
# ~\anaconda3\lib\site-packages\modin\core\execution\dispatching\factories\factories.py in _read_csv(cls, **kwargs)
#     205     )
#     206     def _read_csv(cls, **kwargs):
# --> 207         return cls.io_cls.read_csv(**kwargs)
#     208
#     209     @classmethod
#
# ~\anaconda3\lib\site-packages\modin\core\io\file_dispatcher.py in read(cls, *args, **kwargs)
#     149         postprocessing work on the resulting query_compiler object.
#     150         """
# --> 151         query_compiler = cls._read(*args, **kwargs)
#     152         # TODO (devin-petersohn): Make this section more general for non-pandas kernel
#     153         # implementations.
#
# ~\anaconda3\lib\site-packages\modin\core\io\text\text_file_dispatcher.py in _read(cls, filepath_or_buffer, **kwargs)
#    1005             )
#    1006             f.seek(old_pos)
# -> 1007             splits = cls.partitioned_file(
#    1008                 f,
#    1009                 num_partitions=NPartitions.get(),
#
# ~\anaconda3\lib\site-packages\modin\core\io\text\text_file_dispatcher.py in partitioned_file(cls, f, num_partitions, nrows, skiprows, quotechar, is_quoting, encoding, newline, header_size, pre_reading)
#     263         file_size = cls.file_size(f)
#     264
# --> 265         rows_skipper(header_size)
#     266
#     267         if pre_reading:
#
# ~\anaconda3\lib\site-packages\modin\core\io\text\text_file_dispatcher.py in skipper(n)
#     486                 return 0
#     487             else:
# --> 488                 return cls._read_rows(
#     489                     f,
#     490                     quotechar=quotechar,
#
# ~\anaconda3\lib\site-packages\modin\core\io\text\text_file_dispatcher.py in _read_rows(cls, f, nrows, quotechar, is_quoting, outside_quotes, encoding, newline)
#     384             iterator = f
#     385
# --> 386         for line in iterator:
#     387             if is_quoting and line.count(quotechar) % 2:
#     388                 outside_quotes = not outside_quotes
#
# TypeError: 'LocalFileOpener' object is not iterable
